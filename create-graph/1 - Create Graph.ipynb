# %% [markdown]
# # Demo Boskalis

# %% [markdown]
# ## Create Graph from Project Documents

# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
from pathlib import Path
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pydantic import BaseModel, Field, validator
from typing import List, Optional
from openai import OpenAI
import time
import json
from json import loads, dumps
from neo4j import Query, GraphDatabase, RoutingControl, Result
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from IPython.display import clear_output
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
env_file = '../.env'

# %%
if os.path.exists(env_file):
    load_dotenv(env_file, override=True)

    # Neo4j
    HOST = os.getenv('NEO4J_URI')
    USERNAME = os.getenv('NEO4J_USERNAME')
    PASSWORD = os.getenv('NEO4J_PASSWORD')
    DATABASE = os.getenv('NEO4J_DATABASE')

    # AI
    OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
    os.environ['OPENAI_API_KEY']=OPENAI_API_KEY
    LLM = os.getenv('LLM')
    EMBEDDINGS_MODEL = os.getenv('EMBEDDINGS_MODEL')
else:
    print(f"File {env_file} not found.")

# %%
projects_documents_path = "documents/projects/"
equipment_documents_path = "documents/equipment/"

# %% [markdown]
# ### Test Connection to Neo4j

# %%
driver = GraphDatabase.driver(
    HOST,
    auth=(USERNAME, PASSWORD)
)

# %%
driver.execute_query(
    """
    MATCH (n) RETURN COUNT(n) as Count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    Count
# 0      0

# %% [markdown]
# ## Chunk and Load Documents

# %%
chunk_size = 300
chunk_overlap = 50

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = chunk_size,
    chunk_overlap  = chunk_overlap,
    length_function = len,
    is_separator_regex = False,
)

# %%
def parse_documents(documents_path):
    documents_dir = Path(documents_path)
    chunks_with_metadata = []

    for pdf_path in documents_dir.glob("*.pdf"):
        print(f"Parsing: {pdf_path.name}")
        loader = PyPDFLoader(str(pdf_path))
        pages = loader.load_and_split()
        total_chunks_for_doc = 0
        for page in pages:
            page_chunks = text_splitter.split_text(page.page_content)
            for chunk in page_chunks:
                chunks_with_metadata.append({
                    "doc_path": page.metadata.get("doc_path"),
                    "doc_name": pdf_path.name,
                    "page": page.metadata.get("page"),
                    "text": chunk,
                    "num_chunks": len(page_chunks)
                })
                total_chunks_for_doc += 1
        print(f"Chunked {len(pages)} pages into {total_chunks_for_doc} chunks")
    return pd.DataFrame.from_dict(chunks_with_metadata)

# %%
project_chunks_df = parse_documents(projects_documents_path)
equipment_chunks_df = parse_documents(equipment_documents_path)
# Out:
# Parsing: italy_-_genoa.pdf
# Chunked 2 pages into 21 chunks
# Parsing: FPSo Transportation.pdf
# Chunked 2 pages into 17 chunks
# Parsing: Haven Jack Up Upgrade.pdf
# Chunked 2 pages into 17 chunks
# Parsing: fox_river_leaflet.pdf
# Chunked 1 pages into 6 chunks
# Parsing: uk_-_peterhead.pdf
# Chunked 2 pages into 19 chunks
# Parsing: egypt_-suez_canal.pdf
# Chunked 2 pages into 25 chunks
# Parsing: togo-benin.pdf
# Chunked 3 pages into 36 chunks
# Parsing: Gulhifalhu Phase 2 Maldives.pdf
# Chunked 2 pages into 31 chunks
# Parsing: spain_-_seville.pdf
# Chunked 2 pages into 23 chunks
# Parsing: abu_dhabi_-_khalifa.pdf
# Chunked 4 pages into 41 chunks
# Parsing: 2602020_borssele_alpha.pdf
# Chunked 2 pages into 22 chunks
# Parsing: def_baltic_ii.pdf
# Chunked 2 pages into 25 chunks
# Parsing: suriname-river.pdf
# Chunked 2 pages into 26 chunks
# Parsing: the_netherlands_-_4_nederrijn_measures_room_for_the_river.pdf
# Chunked 2 pages into 21 chunks
# Parsing: a2_holendrecht-maarsen.pdf
# Chunked 2 pages into 23 chunks
# Parsing: netherlands-north_sea-subsea_well_protection_structures_removal.pdf
# Chunked 2 pages into 21 chunks
# Parsing: 20201115_def_wintershall_j6-a.pdf
# Chunked 2 pages into 19 chunks
# Parsing: abu_dhabi_-_khalifa_hydronamic.pdf
# Chunked 3 pages into 34 chunks
# Parsing: the_netherlands_-_maasvlakte2.pdf
# Chunked 3 pages into 29 chunks
# Parsing: Project Sheet LNG Canada Mar 24.pdf
# Chunked 2 pages into 31 chunks
# Parsing: awg-ameland.pdf
# Chunked 2 pages into 23 chunks
# Parsing: Harbor of Lerwick.pdf
# Chunked 2 pages into 26 chunks
# Parsing: le-havre-port-2000.pdf
# Chunked 3 pages into 33 chunks
# Parsing: suriname_lelydorp.pdf
# Chunked 2 pages into 22 chunks
# Parsing: the_netherlands_-_forelands_excavation_deventer__room_for_the_river.pdf
# Chunked 2 pages into 17 chunks
# Parsing: 20181127_aberdeen_bay_offshore_windfarm_project.pdf
# Chunked 2 pages into 23 chunks
# Parsing: russia__st_petersburg.pdf
# Chunked 2 pages into 21 chunks
# Parsing: trailing_suction_hopper_dredger_barent_zanen.pdf
# Chunked 2 pages into 6 chunks
# Parsing: manu-pekka.pdf
# Chunked 2 pages into 5 chunks
# Parsing: ndeavor_mpv.pdf
# Chunked 2 pages into 8 chunks
# Parsing: crestway.pdf
# Chunked 2 pages into 9 chunks
# Parsing: willem-van-oranje.pdf
# Chunked 2 pages into 7 chunks
# Parsing: asian-hercules-iii.pdf
# Chunked 2 pages into 9 chunks
# Parsing: terra-plana.pdf
# Chunked 2 pages into 6 chunks
# Parsing: kamara.pdf
# Chunked 2 pages into 15 chunks
# Parsing: rockpiper.pdf
# Chunked 2 pages into 8 chunks
# Parsing: trailing_suction_hopper_dredger_beachway.pdf
# Chunked 2 pages into 6 chunks
# Parsing: boxer.pdf
# Chunked 2 pages into 10 chunks
# Parsing: strandway.pdf
# Chunked 2 pages into 8 chunks
# Parsing: bear-27-03.pdf
# Chunked 2 pages into 9 chunks
# Parsing: shoalway.pdf
# Chunked 2 pages into 8 chunks
# Parsing: boka-vanguard.pdf
# Chunked 2 pages into 10 chunks
# Parsing: edax.pdf
# Chunked 2 pages into 5 chunks
# Parsing: cornelius-backhoe.pdf
# Chunked 2 pages into 4 chunks
# Parsing: transshelf.pdf
# Chunked 2 pages into 8 chunks
# Parsing: alexii.pdf
# Chunked 2 pages into 6 chunks
# Parsing: ndurance.pdf
# Chunked 2 pages into 10 chunks
# Parsing: bssiii.pdf
# Chunked 2 pages into 17 chunks
# Parsing: giant-7.pdf
# Chunked 2 pages into 10 chunks
# Parsing: waterway.pdf
# Chunked 2 pages into 7 chunks
# Parsing: heavy_transport_vessel_forte.pdf
# Chunked 2 pages into 10 chunks
# Parsing: shoreway.pdf
# Chunked 2 pages into 9 chunks

# %%
project_chunks_df['category'] = 'project'
equipment_chunks_df['category'] = 'equipment'

# %%
chunks_df = pd.concat([project_chunks_df, equipment_chunks_df], ignore_index=True)
chunks_df['chunk_seq_id'] = chunks_df.index + 1

# %%
chunks_df
# Out:
#                                    source           doc_name  page  \
# 0    documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 1    documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 2    documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 3    documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 4    documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# ..                                    ...                ...   ...
# 857      documents/equipment/shoreway.pdf       shoreway.pdf     0
# 858      documents/equipment/shoreway.pdf       shoreway.pdf     0
# 859      documents/equipment/shoreway.pdf       shoreway.pdf     0
# 860      documents/equipment/shoreway.pdf       shoreway.pdf     1
# 861      documents/equipment/shoreway.pdf       shoreway.pdf     1
#
#                                                   text  num_chunks   category  \
# 0    INTRODUCTION\nThe deepening and extension of t...          11    project
# 1    a joint venture with Tecnis S.p.A., an Italian...          11    project
# 2    Genoa. \nSCOPE \nThe work has been split up in...          11    project
# 3    The Trailing Suction Hopper Dredger (TSHD) Ast...          11    project
# 4    B1, work continues on filling up area A1, \nFe...          11    project
# ..                                                 ...         ...        ...
# 857  Max. draught Int. load line  5.70 m\nMax. drau...           7  equipment
# 858  Sailing speed loaded   13.0 kn\nTotal installe...           7  equipment
# 859  Bow thruster   450 kW\nEQUIPMENT\nSHEET\nSHORE...           7  equipment
# 860  The information contained in this data sheet i...           2  equipment
# 861  TOP VIEW DECK LEVEL\nSIDE VIEW\nSHOREWAY\nTRAI...           2  equipment
#
#      chunk_seq_id
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ..            ...
# 857           858
# 858           859
# 859           860
# 860           861
# 861           862
#
# [862 rows x 7 columns]

# %% [markdown]
# ### Load Documents

# %%
document_df = (
    chunks_df.groupby("doc_name").agg(
        doc_path=("doc_path", "max"),
        full_text=("text", " ".join),
        pages=("page", "max"),
        chunks=("num_chunks", "max"),
        category=("category", "max")
    )
    .reset_index()
)
document_df['pages'] = document_df['pages'].apply(lambda x: x + 1)

# %%
document_df
# Out:
#                                              doc_name  \
# 0   20181127_aberdeen_bay_offshore_windfarm_projec...
# 1                   20201115_def_wintershall_j6-a.pdf
# 2                          2602020_borssele_alpha.pdf
# 3                             FPSo Transportation.pdf
# 4                     Gulhifalhu Phase 2 Maldives.pdf
# 5                               Harbor of Lerwick.pdf
# 6                           Haven Jack Up Upgrade.pdf
# 7                 Project Sheet LNG Canada Mar 24.pdf
# 8                          a2_holendrecht-maarsen.pdf
# 9                             abu_dhabi_-_khalifa.pdf
# 10                 abu_dhabi_-_khalifa_hydronamic.pdf
# 11                                         alexii.pdf
# 12                             asian-hercules-iii.pdf
# 13                                    awg-ameland.pdf
# 14                                     bear-27-03.pdf
# 15                                  boka-vanguard.pdf
# 16                                          boxer.pdf
# 17                                         bssiii.pdf
# 18                              cornelius-backhoe.pdf
# 19                                       crestway.pdf
# 20                                  def_baltic_ii.pdf
# 21                                           edax.pdf
# 22                              egypt_-suez_canal.pdf
# 23                              fox_river_leaflet.pdf
# 24                                        giant-7.pdf
# 25                   heavy_transport_vessel_forte.pdf
# 26                                  italy_-_genoa.pdf
# 27                                         kamara.pdf
# 28                             le-havre-port-2000.pdf
# 29                                     manu-pekka.pdf
# 30                                    ndeavor_mpv.pdf
# 31                                       ndurance.pdf
# 32  netherlands-north_sea-subsea_well_protection_s...
# 33                                      rockpiper.pdf
# 34                          russia__st_petersburg.pdf
# 35                                       shoalway.pdf
# 36                                       shoreway.pdf
# 37                                spain_-_seville.pdf
# 38                                      strandway.pdf
# 39                                 suriname-river.pdf
# 40                              suriname_lelydorp.pdf
# 41                                    terra-plana.pdf
# 42  the_netherlands_-_4_nederrijn_measures_room_fo...
# 43  the_netherlands_-_forelands_excavation_devente...
# 44                  the_netherlands_-_maasvlakte2.pdf
# 45                                     togo-benin.pdf
# 46   trailing_suction_hopper_dredger_barent_zanen.pdf
# 47       trailing_suction_hopper_dredger_beachway.pdf
# 48                                     transshelf.pdf
# 49                                 uk_-_peterhead.pdf
# 50                                       waterway.pdf
# 51                              willem-van-oranje.pdf
#
#                                                source  \
# 0   documents/projects/20181127_aberdeen_bay_offsh...
# 1   documents/projects/20201115_def_wintershall_j6...
# 2       documents/projects/2602020_borssele_alpha.pdf
# 3          documents/projects/FPSo Transportation.pdf
# 4   documents/projects/Gulhifalhu Phase 2 Maldives...
# 5            documents/projects/Harbor of Lerwick.pdf
# 6        documents/projects/Haven Jack Up Upgrade.pdf
# 7   documents/projects/Project Sheet LNG Canada Ma...
# 8       documents/projects/a2_holendrecht-maarsen.pdf
# 9          documents/projects/abu_dhabi_-_khalifa.pdf
# 10  documents/projects/abu_dhabi_-_khalifa_hydrona...
# 11                     documents/equipment/alexii.pdf
# 12         documents/equipment/asian-hercules-iii.pdf
# 13                 documents/projects/awg-ameland.pdf
# 14                 documents/equipment/bear-27-03.pdf
# 15              documents/equipment/boka-vanguard.pdf
# 16                      documents/equipment/boxer.pdf
# 17                     documents/equipment/bssiii.pdf
# 18          documents/equipment/cornelius-backhoe.pdf
# 19                   documents/equipment/crestway.pdf
# 20               documents/projects/def_baltic_ii.pdf
# 21                       documents/equipment/edax.pdf
# 22           documents/projects/egypt_-suez_canal.pdf
# 23           documents/projects/fox_river_leaflet.pdf
# 24                    documents/equipment/giant-7.pdf
# 25  documents/equipment/heavy_transport_vessel_for...
# 26               documents/projects/italy_-_genoa.pdf
# 27                     documents/equipment/kamara.pdf
# 28          documents/projects/le-havre-port-2000.pdf
# 29                 documents/equipment/manu-pekka.pdf
# 30                documents/equipment/ndeavor_mpv.pdf
# 31                   documents/equipment/ndurance.pdf
# 32  documents/projects/netherlands-north_sea-subse...
# 33                  documents/equipment/rockpiper.pdf
# 34       documents/projects/russia__st_petersburg.pdf
# 35                   documents/equipment/shoalway.pdf
# 36                   documents/equipment/shoreway.pdf
# 37             documents/projects/spain_-_seville.pdf
# 38                  documents/equipment/strandway.pdf
# 39              documents/projects/suriname-river.pdf
# 40           documents/projects/suriname_lelydorp.pdf
# 41                documents/equipment/terra-plana.pdf
# 42  documents/projects/the_netherlands_-_4_nederri...
# 43  documents/projects/the_netherlands_-_forelands...
# 44  documents/projects/the_netherlands_-_maasvlakt...
# 45                  documents/projects/togo-benin.pdf
# 46  documents/equipment/trailing_suction_hopper_dr...
# 47  documents/equipment/trailing_suction_hopper_dr...
# 48                 documents/equipment/transshelf.pdf
# 49              documents/projects/uk_-_peterhead.pdf
# 50                   documents/equipment/waterway.pdf
# 51          documents/equipment/willem-van-oranje.pdf
#
#                                             full_text  pages  chunks  \
# 0   A At the fabrication Yard in Newcastle\nA\nPRO...      2      16
# 1   PROJECT\nSHEET\nUMBILICAL REPLACEMENT AND  \nA...      2      11
# 2   A Schematic of cable route with in yellow the ...      2      13
# 3   FEATURES\nClient COOEC (Offshore Oil Engineeri...      2      10
# 4   A Gulhifalhu south east corner\nB Revetment in...      2      16
# 5   INTRODUCTION \nThe Port of Lerwick is situated...      2      15
# 6   FEATURES\nClient Lamprell\nCompany Master Mari...      2       9
# 7   A Overview of project site\nB Trailing suction...      2      16
# 8   PROJECT \nSHEET\nHOLENDRECHT - MAARSSEN, THE N...      2      14
# 9   INTRODUCTION \nThe Khalifa Port and Industrial...      4      15
# 10  INTRODUCTION \nThe overall KPIZ Project develo...      2      17
# 11  CONSTRUCTION / CLASSIFICATION\nBuilt by  Yizhe...      2       4
# 12  EQUIPMENT\nSHEET\nASIAN HERCULES III\n5,000 TO...      2       6
# 13  A CLV Spirit and the platform\nA\nPROJECT\nSHE...      2      13
# 14  EQUIPMENT\nSHEET\nBEAR\nOFFSHORE VESSELS /  \n...      2       5
# 15  EQUIPMENT\nSHEET\nBOKA VANGUARD\nSEMI-SUBMERSI...      2       7
# 16  EQUIPMENT\nSHEET\nBOXER\nOFFSHORE VESSELS / AN...      2       6
# 17  EQUIPMENT\nSHEET\nBSSIII\nBURIAL SLEDGE SYSTEM...      2       9
# 18  CONSTRUCTION/CLASSIFICATION\nBuilt by  De Dong...      2       2
# 19  CONSTRUCTION / CLASSIFICATION\nBuilt by  IHC D...      2       7
# 20  BOSKALIS’ ENERGY SOLUTIONS\nBoskalis is a lead...      2      15
# 21  EQUIPMENT\nSHEET\nEDAX\nCUTTER SUCTION DREDGER...      2       3
# 22  COMPLEX PLANNING\nTo ensure the project was co...      2      15
# 23  Stuyvesant’s affiliated company Boskalis Dolma...      1       6
# 24  CONSTRUCTION / CLASSIFICATION\nYear of constru...      2       5
# 25  EQUIPMENT\nSHEET\nFORTE\nSEMI-SUBMERSIBLE DP-2...      2       7
# 26  INTRODUCTION\nThe deepening and extension of t...      2      11
# 27  EQUIPMENT\nSHEET\nKAMARA\nDP II OFFSHORE VESSE...      2       9
# 28  A TSHD Strandway and TSHD Shoalway\nB TSHD Wil...      3      14
# 29  MAIN DATA\nGross tonnage 680 GT\nLength overal...      2       3
# 30  EQUIPMENT\nSHEET\nNDEAVOR\nMULTIPURPOSE VESSEL...      2       6
# 31  EQUIPMENT\nSHEET\nNDURANCE \nCABLE LAYING VESS...      2       6
# 32  FEATURES\nLocation Southern North Sea\nPeriod ...      2      12
# 33  CONSTRUCTION / CLASSIFICATION\nVessel built by...      2       6
# 34  INTRODUCTION \nSt. Petersburg is a UNESCO Worl...      2      12
# 35  CONSTRUCTION / CLASSIFICATION\nBuilt by  Inter...      2       6
# 36  CONSTRUCTION / CLASSIFICATION\nBuilt by  IHC D...      2       7
# 37  INTRODUCTION\nSeville is located 80 km land in...      2      14
# 38  CONSTRUCTION / CLASSIFICATION\nBuilt by  Shipk...      2       6
# 39  BOSKALIS\nBoskalis is a leading global marine ...      2      14
# 40  A\nPROJECT \nSHEET\nLELYDORP, SURINAME\nBAUXIT...      2      12
# 41  MAIN DATA\nLength overall 39.8 m\nLength b.p.p...      2       4
# 42  PROJECT\nSHEET\n4 NEDERRIJN MEASURES\nROOM FOR...      2      14
# 43  PROJECT\nSHEET\nFORELANDS EXCAVATION DEVENTER\...      2      10
# 44  INTRODUCTION\nPUMA, the Project Organization f...      2      15
# 45  A\nFEATURES\nClient Government of Togo and Ben...      3      13
# 46  MAIN DATA\nGross tonnage 9,773\nLength overall...      2       4
# 47  CONSTRUCTION / CLASSIFICATION\nVessel built by...      2       4
# 48  EQUIPMENT\nSHEET\nTRANSSHELF\nSEMI-SUBMERSIBLE...      2       6
# 49  PROJECT DESCRIPTION \nThe project consisted of...      2      12
# 50  CONSTRUCTION / CLASSIFICATION\nBuilt by Merwed...      2       5
# 51  CONSTRUCTION / CLASSIFICATION\nBuilt by IHC Dr...      2       5
#
#      category
# 0     project
# 1     project
# 2     project
# 3     project
# 4     project
# 5     project
# 6     project
# 7     project
# 8     project
# 9     project
# 10    project
# 11  equipment
# 12  equipment
# 13    project
# 14  equipment
# 15  equipment
# 16  equipment
# 17  equipment
# 18  equipment
# 19  equipment
# 20    project
# 21  equipment
# 22    project
# 23    project
# 24  equipment
# 25  equipment
# 26    project
# 27  equipment
# 28    project
# 29  equipment
# 30  equipment
# 31  equipment
# 32    project
# 33  equipment
# 34    project
# 35  equipment
# 36  equipment
# 37    project
# 38  equipment
# 39    project
# 40    project
# 41  equipment
# 42    project
# 43    project
# 44    project
# 45    project
# 46  equipment
# 47  equipment
# 48  equipment
# 49    project
# 50  equipment
# 51  equipment

# %% [markdown]
# Load URL's of Documents

# %%
PAGE = "https://boskalis.com/download-center"
BASE = "https://boskalis.com"

# %%
def fetch_pdf_table():
    r = requests.get(PAGE, headers={"User-Agent": "Mozilla/5.0"}, timeout=20)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")

    rows = []
    seen = set()

    for a in soup.find_all("a", href=True):
        href = a["href"].split("?")[0].strip()
        if href.lower().endswith(".pdf"):
            full = href if href.startswith("http") else urljoin(BASE, href)
            if full in seen:
                continue
            seen.add(full)
            file_name = full.rstrip("/").split("/")[-1]  # keep .pdf
            rows.append({"doc_name": file_name, "url": full})

    df = pd.DataFrame(rows).drop_duplicates().reset_index(drop=True)
    return df

# %%
urls_df = fetch_pdf_table()

# %%
document_df = pd.merge(document_df, urls_df, on="doc_name", how="left")

# %%
merge_document_query = """
    MERGE(mergedDocument:Document {name: $doc_name})
    SET mergedDocument.doc_path = $doc_path,
        mergedDocument.full_text = $full_text,
        mergedDocument.pages = $pages,
        mergedDocument.chunks = $chunks,
        mergedDocument.category = $category,
        mergedDocument.url = $url
        
    RETURN mergedDocument
    """

# %%
for index, row in document_df.iterrows():
    clear_output(wait=True)
    driver.execute_query(
        merge_document_query,
        database_=DATABASE,
        routing_=RoutingControl.WRITE,
        doc_name = row.doc_name,
        doc_path = row.doc_path,
        full_text = row.full_text,
        pages = row.pages,
        chunks = row.chunks,
        category = row.category,
        url = row.url,
    )
    print(f"Loaded {row['doc_name']}")
    print("Progress: ", np.round((index+1)/document_df.shape[0]*100,2), "%")
# Out:
# Loaded willem-van-oranje.pdf
# Progress:  100.0 %

# %% [markdown]
# ### Load Chunks

# %% [markdown]
# First add Embeddings

# %%
embeddings_model = OpenAIEmbeddings(
    model = EMBEDDINGS_MODEL,
    openai_api_key = OPENAI_API_KEY
)

# %% [markdown]
# Add an embedding for every chunk in the DataFrame

# %%
chunks_df['embedding'] = chunks_df['text'].apply(lambda x: embeddings_model.embed_query(x))

# %%
chunks_df.head()
# Out:
#                                  source           doc_name  page  \
# 0  documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 1  documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 2  documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 3  documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
# 4  documents/projects/italy_-_genoa.pdf  italy_-_genoa.pdf     0
#
#                                                 text  num_chunks category  \
# 0  INTRODUCTION\nThe deepening and extension of t...          11  project
# 1  a joint venture with Tecnis S.p.A., an Italian...          11  project
# 2  Genoa. \nSCOPE \nThe work has been split up in...          11  project
# 3  The Trailing Suction Hopper Dredger (TSHD) Ast...          11  project
# 4  B1, work continues on filling up area A1, \nFe...          11  project
#
#    chunk_seq_id                                          embedding
# 0             1  [0.006220303475856781, -0.0248403362929821, 0....
# 1             2  [0.007828463800251484, -0.025723079219460487, ...
# 2             3  [-0.003091271501034498, -0.02294781804084778, ...
# 3             4  [-0.006104578264057636, -0.005901559256017208,...
# 4             5  [-0.0036728905979543924, -0.03611675649881363,...

# %%
merge_chunck_query = """
    MERGE(c:Chunk {id: $chunk_seq_id})
        ON CREATE SET
            c.page = $page,
            c.text = $text,
            c.embedding = $embedding
    WITH c
    MATCH (d:Document{name: $doc_name})
    MERGE (c)-[r:PART_OF]->(d)
"""

# %%
for index, row in chunks_df.iterrows():
    clear_output(wait=True)
    driver.execute_query(
        merge_chunck_query,
        database_=DATABASE,
        routing_=RoutingControl.WRITE,
        chunk_seq_id = row.chunk_seq_id,
        page = row.page,
        text = row.text,
        embedding = row.embedding,
        doc_name = row.doc_name
    )
    print("Progress: ", np.round(((index+1)/chunks_df.shape[0])*100,2), "%")
# Out:
# Progress:  100.0 %

# %% [markdown]
# ## Project Entities

# %% [markdown]
# Let's extract projects from a Project Documents

# %% [markdown]
# ### Extract Project Entities

# %%
class Location(BaseModel):
    """
    Represents the location of a project
    """
    location: str = Field(..., description="Location were the project was carried out")
    country: str =  Field(..., description="Country where the location is based")
    country_code: str = Field(..., description="Country code according to the ISO 3166-1 alpha-3 country codes")

class Equipment(BaseModel):
    """
    Represents the Equipment used in the project. This class contains one equipment with its specific name and no generic name.
    """
    name: str = Field(..., description="Name of the equipment used in the project")
    description: Optional[str] =  Field(..., description="Short description of the equipment useded in the project if provided")

class Contractor(BaseModel):
    """
    Represents a Contractor of a project
    """
    name: str = Field(..., description="Name of the contractor of the project")
    description: Optional[str] =  Field(..., description="Short description of the contractor if provided")

class Client(BaseModel):
    """
    Represents a client of a project
    """
    name: str = Field(..., description="Name of the client of the project")
    description: Optional[str] =  Field(..., description="Short description of the client if provided")

class Project(BaseModel):
    """
    Represents a question with answer from the press conferences with ECB.
    """
    doc_path: str = Field(..., description="The path of the document")
    name: str = Field(..., description="The name of the project")
    date: str = Field(..., description="The date of the project")
    description: str = Field(..., description="Short description of the project that was carried out")
    client: List[Client] = Field(..., description="List of clients for this project")
    contractor: List[Contractor] = Field(..., description="List of contractors for this project")
    equipment: List[Equipment] = Field(..., description="List of equipment used in this project. If multiple equipment is used split into different objects.")
    location: List[Location] = Field(..., description="Location of this project")

class ProjectList(BaseModel):
    """
    Represents a list of projects based carried out. 
    """
    projects: List[Project]

# %%
system_message = """
    You are an expert in extracting structured information text. 
    In this case we want to extract Information of projects from documents. The text is coming from short documents on a project carried out by Boskalis.
    Please extract the information as specified in the provided format.

    Identify details such as:
    - Project that is carried out.
    - More information like equipment used, contractor, client and location the project was carried out.
    - Please be specific on the contractor. Typically these are different entities of Boskalis. 
    - If a description is asked, please generate a short summary based on the text.
    - For Equipment use the specific name of that equipment no generic names as (e.g. ignore Grab dredger, Suction Hopper Dredger, etc). 

    Don't come up with anything yourself. Just base it on the documents fully.
"""

# %%
client = OpenAI()

# %%
def extract(document, model=LLM, temperature=0):
    response = client.beta.chat.completions.parse(
        model=model,
        temperature=temperature,
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": document},
        ],
        response_format=ProjectList,
    )
    return json.loads(response.choices[0].message.content)

# %%
columns = ['doc_path', 'name', 'date', 'description', 'client', 'contractor', 'equipment', 'location']
projects_df = pd.DataFrame(columns=columns)

# %%
project_documents_df = document_df[document_df['category'] == 'project'].reset_index(drop=True)

for idx, row in project_documents_df.iterrows():
    text = project_documents_df['full_text'].iloc[idx]
    extracted_projects = extract("Document Path:" + project_documents_df['doc_path'].iloc[idx] + "\n" + text)
    ProjectList.model_validate(extracted_projects)
    df = pd.json_normalize(extracted_projects["projects"])
    projects_df = pd.concat([projects_df, df], ignore_index=True)

# %%
projects_df
# Out:
#                                                source  \
# 0   documents/projects/20181127_aberdeen_bay_offsh...
# 1   documents/projects/20201115_def_wintershall_j6...
# 2       documents/projects/2602020_borssele_alpha.pdf
# 3          documents/projects/FPSo Transportation.pdf
# 4   documents/projects/Gulhifalhu Phase 2 Maldives...
# 5            documents/projects/Harbor of Lerwick.pdf
# 6        documents/projects/Haven Jack Up Upgrade.pdf
# 7   documents/projects/Project Sheet LNG Canada Ma...
# 8       documents/projects/a2_holendrecht-maarsen.pdf
# 9          documents/projects/abu_dhabi_-_khalifa.pdf
# 10  documents/projects/abu_dhabi_-_khalifa_hydrona...
# 11                 documents/projects/awg-ameland.pdf
# 12               documents/projects/def_baltic_ii.pdf
# 13           documents/projects/egypt_-suez_canal.pdf
# 14           documents/projects/fox_river_leaflet.pdf
# 15               documents/projects/italy_-_genoa.pdf
# 16          documents/projects/le-havre-port-2000.pdf
# 17  documents/projects/netherlands-north_sea-subse...
# 18       documents/projects/russia__st_petersburg.pdf
# 19             documents/projects/spain_-_seville.pdf
# 20              documents/projects/suriname-river.pdf
# 21           documents/projects/suriname_lelydorp.pdf
# 22  documents/projects/the_netherlands_-_4_nederri...
# 23  documents/projects/the_netherlands_-_forelands...
# 24  documents/projects/the_netherlands_-_maasvlakt...
# 25                  documents/projects/togo-benin.pdf
# 26              documents/projects/uk_-_peterhead.pdf
#
#                                                  name  \
# 0              Aberdeen Bay Offshore Windfarm Project
# 1   Umbilical Replacement and Accumulator Rack Cha...
# 2                   Borssele Alpha/Beta Export Cables
# 3                             P67 FPSO Transportation
# 4                                  Gulhifalhu Phase 2
# 5    North Harbor of Lerwick Dredging and Reclamation
# 6                               Haven Jack-Up Upgrade
# 7           LNG Canada Dredging and Disposal Services
# 8   Reconstruction of A2 Motorway Holendrecht-Maar...
# 9     Khalifa Port and Industrial Zone (KPIZ) Project
# 10    Khalifa Port and Industrial Zone (KPIZ) Project
# 11                                        AWG Ameland
# 12                       Baltic II Offshore Wind Farm
# 13                    New Suez Canal Dredging Project
# 14                                  Fox River Cleanup
# 15   Deepening and Extending the Port of Genoa, Italy
# 16  Le Havre Port 2000 3rd Phase - Realization of ...
# 17          Subsea Well Protection Structures Removal
# 18  Completing a Flood Protection Barrier, a Navig...
# 19  Port of Seville Maritime Access Improvement Ca...
# 20                    Suriname River Dredging Project
# 21                         Bauxite Mining in Lelydorp
# 22          4 Nederrijn Measures - Room for the River
# 23  Forelands Excavation Deventer - Room for the R...
# 24                                       Maasvlakte 2
# 25      Cross-Border Coastal Protection, Togo - Benin
# 26             Peterhead Smith Embankment Development
#
#                               date  \
# 0                      2016 - 2018
# 1                         Q2, 2019
# 2                      2018 - 2020
# 3                             2018
# 4                      2023 - 2024
# 5                      2007 – 2008
# 6          January - February 2018
# 7                      2018 - 2021
# 8          October 2006 – mid-2012
# 9      October 2007 – January 2012
# 10                 2008-02/2010-09
# 11                     2020 - 2021
# 12    December 2013 - October 2014
# 13     November 2014 – August 2015
# 14                            2008
# 15                       2009-2014
# 16   November 2019 - December 2022
# 17                     2014 - 2016
# 18         August 2006 to May 2011
# 19                     2006 - 2010
# 20        October 2022 - July 2023
# 21                     2011 - 2015
# 22                     2011 - 2014
# 23                     2011 - 2015
# 24                     2008 - 2013
# 25  February 2022 - September 2023
# 26     April 2009 – September 2010
#
#                                           description  \
# 0   The Aberdeen Bay Offshore Windfarm Project, al...
# 1   The project involved replacing the SSIV contro...
# 2   The project involved the supply and installati...
# 3   Boskalis executed the dry transportation of th...
# 4   The Gulhifalhu Phase 2 project involved the ex...
# 5   The project involved dredging and reclamation ...
# 6   The Haven Jack-Up Upgrade project involved the...
# 7   Boskalis was involved in the LNG Canada projec...
# 8   The project involved the reconstruction and wi...
# 9   The Khalifa Port and Industrial Zone (KPIZ) pr...
# 10  The project involves the relocation of Port Za...
# 11  Boskalis was contracted by NAM for the cable i...
# 12  Boskalis was involved in the Baltic II Offshor...
# 13  The project involved dredging a 35 km long New...
# 14  The Fox River Cleanup project involves dredgin...
# 15  The project involved deepening and extending t...
# 16  The project involved the construction of 700 m...
# 17  Boskalis was contracted to remove Subsea Well ...
# 18  The project involved the construction of a sto...
# 19  The project involved the deepening and widenin...
# 20  The project involved deepening and widening th...
# 21  Boskalis International was contracted by Sural...
# 22  The project involved expanding the foreland of...
# 23  The project aimed to improve water safety by e...
# 24  The Maasvlakte 2 project involved the extensio...
# 25  The project aimed to protect a 14 km long cros...
# 26  The project involved capital dredging, reclama...
#
#                                                client  \
# 0       [{'name': 'Vattenfall', 'description': None}]
# 1   [{'name': 'Wintershall Noordzee B.V.', 'descri...
# 2   [{'name': 'Tennet TSO B.V.', 'description': No...
# 3   [{'name': 'COOEC (Offshore Oil Engineering Co....
# 4   [{'name': 'Government of the Republic of Maldi...
# 5   [{'name': 'Lerwick Port Authority', 'descripti...
# 6         [{'name': 'Lamprell', 'description': None}]
# 7   [{'name': 'LNG Canada Development Inc., Shell'...
# 8   [{'name': 'Rijkswaterstaat', 'description': 'D...
# 9   [{'name': 'Abu Dhabi Ports Company (ADPC)', 'd...
# 10  [{'name': 'Abu Dhabi Port Company (ADPC)', 'de...
# 11  [{'name': 'NAM (Nederlandse Aardolie Maatschap...
# 12         [{'name': 'EnBW AG', 'description': None}]
# 13  [{'name': 'Suez Canal Authority', 'description...
# 14      [{'name': 'Tetra Tech', 'description': None}]
# 15  [{'name': 'Port Authority of Genoa', 'descript...
# 16  [{'name': 'Grand Port Maritime du Havre', 'des...
# 17                                                 []
# 18  [{'name': 'Ministry of Regional Development of...
# 19  [{'name': 'Autoridad Portuaria de Sevilla', 'd...
# 20  [{'name': 'Ministry of Public Works of the Rep...
# 21  [{'name': 'Suralco L.L.C.', 'description': 'An...
# 22  [{'name': 'Directorate-General for Public Work...
# 23  [{'name': 'Water Board Groot Salland', 'descri...
# 24  [{'name': 'Rotterdam Port Authority', 'descrip...
# 25  [{'name': 'Government of Togo and Benin - Mini...
# 26  [{'name': 'Peterhead Port Authority', 'descrip...
#
#                                            contractor  \
# 0   [{'name': 'Boskalis', 'description': 'Royal Bo...
# 1   [{'name': 'Boskalis', 'description': 'Royal Bo...
# 2   [{'name': 'VBNK (consortium Boskalis Subsea Ca...
# 3   [{'name': 'Royal Boskalis Westminster', 'descr...
# 4   [{'name': 'Boskalis Westminster Contracting Li...
# 5   [{'name': 'Westminster Dredging Co.', 'descrip...
# 6   [{'name': 'Royal Boskalis Westminster', 'descr...
# 7   [{'name': 'Boskalis', 'description': 'Boskalis...
# 8   [{'name': 'A2HoMa consortium', 'description': ...
# 9   [{'name': 'Khalifa Port Marine Consortium (KPM...
# 10  [{'name': 'Boskalis Middle East Ltd', 'descrip...
# 11  [{'name': 'Boskalis Subsea Cables B.V.', 'desc...
# 12  [{'name': 'ArGe – JV Hochtief, GeoSea Nordsee'...
# 13  [{'name': 'Challenge Consortium', 'description...
# 14  [{'name': 'Stuyvesant Environmental Contractin...
# 15  [{'name': 'Boskalis Italia S.r.l.', 'descripti...
# 16  [{'name': 'Joint Venture Soletanche Bachy - At...
# 17  [{'name': 'Boskalis Offshore Marine Contractin...
# 18  [{'name': 'Boskalis bv', 'description': 'Sole ...
# 19  [{'name': 'Esclusa Sevilla UTE', 'description'...
# 20  [{'name': 'Boskalis International BV', 'descri...
# 21  [{'name': 'Boskalis International', 'descripti...
# 22  [{'name': 'Boskalis Nederland B.V.', 'descript...
# 23  [{'name': 'IJsselfront Consortium', 'descripti...
# 24  [{'name': 'PUMA', 'description': 'A joint vent...
# 25  [{'name': 'Boskalis International BV', 'descri...
# 26  [{'name': 'Westminster Dredging Co. Ltd.', 'de...
#
#                                             equipment  \
# 0   [{'name': 'Asian Hercules III', 'description':...
# 1   [{'name': 'DSV ‘EDT Protea’', 'description': N...
# 2   [{'name': 'Cable Lay Barge Giant 7', 'descript...
# 3   [{'name': 'MV Boka Vanguard', 'description': '...
# 4   [{'name': 'Oranje', 'description': 'A trailing...
# 5   [{'name': 'TSHD Waterway', 'description': 'Use...
# 6   [{'name': 'Asian Hercules III', 'description':...
# 7   [{'name': 'Beachway', 'description': 'Trailing...
# 8   [{'name': 'Hydronamic', 'description': 'Boskal...
# 9   [{'name': 'TsHD Alpha B', 'description': 'A sh...
# 10                                                 []
# 11  [{'name': 'Boka Spirit', 'description': 'Cable...
# 12  [{'name': 'Taklift 4', 'description': 'A self-...
# 13  [{'name': 'Cutter suction dredger Edax', 'desc...
# 14  [{'name': 'Membrane Plate and Frame Presses', ...
# 15  [{'name': 'TSHD Astra', 'description': 'A Trai...
# 16  [{'name': 'TSHD Shoalway', 'description': None...
# 17  [{'name': 'Taklift 4', 'description': 'A heavy...
# 18  [{'name': 'TSHd 'Barent Zanen'', 'description'...
# 19  [{'name': 'CSD Para I', 'description': 'A 3,40...
# 20  [{'name': 'TSHD Crestway', 'description': 'A t...
# 21  [{'name': 'Orion', 'description': 'A Boskalis ...
# 22                                                 []
# 23                                                 []
# 24  [{'name': 'TSHD ‘Oranje’', 'description': None...
# 25  [{'name': 'TSHD Willem van Oranje', 'descripti...
# 26  [{'name': 'Manu Pekka', 'description': 'Backho...
#
#                                              location
# 0   [{'location': 'Aberdeen, Scotland', 'country':...
# 1   [{'location': 'Block J6-A', 'country': 'The Ne...
# 2   [{'location': 'Borssele', 'country': 'Netherla...
# 3   [{'location': 'Shanghai', 'country': 'China', ...
# 4   [{'location': 'Gulhifalhu Lagoon, North Malé A...
# 5   [{'location': 'Port of Lerwick, Scotland', 'co...
# 6   [{'location': 'CCB Ågotnes', 'country': 'Norwa...
# 7   [{'location': 'Kitimat, British Columbia', 'co...
# 8   [{'location': 'A2 Motorway, Utrecht – Amsterda...
# 9   [{'location': 'Al Taweelah, Abu Dhabi', 'count...
# 10  [{'location': 'Abu Dhabi', 'country': 'United ...
# 11  [{'location': 'Ameland', 'country': 'Netherlan...
# 12  [{'location': 'Baltic Sea, approximately 32 km...
# 13  [{'location': 'Suez Canal', 'country': 'Egypt'...
# 14  [{'location': 'Green Bay, Wisconsin', 'country...
# 15  [{'location': 'Genoa', 'country': 'Italy', 'co...
# 16  [{'location': 'Le Havre', 'country': 'France',...
# 17  [{'location': 'Southern North Sea', 'country':...
# 18  [{'location': 'St. Petersburg', 'country': 'Ru...
# 19  [{'location': 'Seville', 'country': 'Spain', '...
# 20  [{'location': 'Paramaribo', 'country': 'Surina...
# 21  [{'location': 'Lelydorp', 'country': 'Suriname...
# 22  [{'location': 'Elst (U), Lienden, Doorwerth', ...
# 23  [{'location': 'Deventer', 'country': 'Netherla...
# 24  [{'location': 'Port of Rotterdam', 'country': ...
# 25  [{'location': 'Coastline from Grand Popo, Beni...
# 26  [{'location': 'Peterhead, Aberdeenshire', 'cou...

# %% [markdown]
# ### Load Projects to Neo4j

# %%
CREATE_PROJECT_QUERY = """
MERGE (p:Project {name: $name})
SET  p.doc_path = $doc_path,
     p.date = $date,
     p.description = $description

WITH p
CALL (p) {
    MATCH (d:Document{doc_path: $doc_path})
    MERGE (p)-[:HAS_DOCUMENT]->(d)
}

WITH p
CALL (p) {
    UNWIND $clients AS c
    MERGE (client:Client {name: c.name})
    SET client.description = c.description
    MERGE (p)-[:HAS_CLIENT]->(client)
}

WITH p
CALL (p) {
    UNWIND $contractors AS ct
    MERGE (contractor:Contractor {name: ct.name})
    SET contractor.description = ct.description
    MERGE (p)-[:HAS_CONTRACTOR]->(contractor)
}

WITH p
CALL (p) {
    UNWIND $equipment AS e
    MERGE (eq:Equipment {name: e.name})
    SET eq.description = e.description
    MERGE (p)-[:USED_EQUIPMENT]->(eq)
}

WITH p
CALL (p) {
    UNWIND $locations AS l
    MERGE (loc:Location {name: l.location})
    MERGE (country:Country {code: l.country_code})
    SET country.name = l.country
    MERGE (loc)-[:IN_COUNTRY]->(country)
    MERGE (p)-[:AT_LOCATION]->(loc)
};
"""

# %%
def insert_project_row(row):
    driver.execute_query(
        CREATE_PROJECT_QUERY,
        name=row["name"],
        doc_path=row["doc_path"],
        date=row["date"],
        description=row["description"],
        clients=row["client"],
        contractors=row["contractor"],
        equipment=row["equipment"],
        locations=row["location"],     
        database_=DATABASE,
        routing_=RoutingControl.WRITE,
    )

# %%
for idx, row in projects_df.iterrows():
    insert_project_row(row)

# %%
driver.execute_query(
    """
    MATCH (p:Project) RETURN COUNT(p) AS project_count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_=lambda r: r.to_df()
)
# Out:
#    project_count
# 0             26

# %% [markdown]
# ## Equipment Entities

# %% [markdown]
# Let's extract projects from a Equipment Documents

# %% [markdown]
# ### Extract Equipment Entities

# %%
class Location(BaseModel):
    """
    Represents the location of equipment
    """
    location: str = Field(..., description="Location were the equipment was registered")
    country: str =  Field(..., description="Country where the location is based")
    country_code: str = Field(..., description="Country code according to the ISO 3166-1 alpha-3 country codes")

class Equipment(BaseModel):
    """
    Represents the equipment that can be used in projects
    """
    doc_path: str = Field(..., description="The path of the document")
    name: str = Field(..., description="Name of the equipment used in the project")
    year_of_construction: Optional[int] =  Field(..., description="Year of the equipment being constructed")
    capacity: Optional[str] =  Field(..., description="Capacity of the equipment")
    built_by: Optional[str] =  Field(..., description="Company the equipment was being built by")
    imo_number: Optional[int] =  Field(..., description="The IMO (International Maritime Organization)")
    port_of_registery: List[Location] = Field(..., description="Location of the port of registery of this equipment")
    description: Optional[str] =  Field(..., description="Short description of the equipment useded in the project if provided")

class EquipmentList(BaseModel):
    """
    Represents a list of equipment described in the documents. 
    """
    equipments: List[Equipment]

# %%
system_message = """
    You are an expert in extracting structured information text. 
    In this case we want to extract information of equipment from documents. The text is coming from short documents on equipment of Boskalis.
    Please extract the information as specified in the provided format.

    Identify details such as:
    - Equipment that is described.
    - More properties like description, capacity, year of construction, classification etc. 

    Don't come up with anything yourself. Just base it on the documents fully.
"""

# %%
client = OpenAI()

# %%
def extract(document, model=LLM, temperature=0):
    response = client.beta.chat.completions.parse(
        model=model,
        temperature=temperature,
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": document},
        ],
        response_format=EquipmentList,
    )
    return json.loads(response.choices[0].message.content)

# %%
columns = ['doc_path', 'name', 'year_of_construction', 'capacity', 'built_by', 'imo_number', 'port_of_registery', 'description']
equipment_df = pd.DataFrame(columns=columns)

# %%
equipment_documents_df = document_df[document_df['category'] == 'equipment'].reset_index(drop=True)

for idx, row in equipment_documents_df.iterrows():
    text = equipment_documents_df['full_text'].iloc[idx]
    extracted_equipments = extract("Document Path:" + equipment_documents_df['doc_path'].iloc[idx] + "\n" + text)
    EquipmentList.model_validate(extracted_equipments)
    df = pd.json_normalize(extracted_equipments["equipments"])
    equipment_df = pd.concat([equipment_df, df], ignore_index=True)

# %%
equipment_df
# Out:
#                                                source  \
# 0                      documents/equipment/alexii.pdf
# 1          documents/equipment/asian-hercules-iii.pdf
# 2                  documents/equipment/bear-27-03.pdf
# 3               documents/equipment/boka-vanguard.pdf
# 4                       documents/equipment/boxer.pdf
# 5                      documents/equipment/bssiii.pdf
# 6           documents/equipment/cornelius-backhoe.pdf
# 7                    documents/equipment/crestway.pdf
# 8                        documents/equipment/edax.pdf
# 9                     documents/equipment/giant-7.pdf
# 10  documents/equipment/heavy_transport_vessel_for...
# 11                     documents/equipment/kamara.pdf
# 12                 documents/equipment/manu-pekka.pdf
# 13                documents/equipment/ndeavor_mpv.pdf
# 14                   documents/equipment/ndurance.pdf
# 15                  documents/equipment/rockpiper.pdf
# 16                   documents/equipment/shoalway.pdf
# 17                   documents/equipment/shoreway.pdf
# 18                  documents/equipment/strandway.pdf
# 19                documents/equipment/terra-plana.pdf
# 20  documents/equipment/trailing_suction_hopper_dr...
# 21  documents/equipment/trailing_suction_hopper_dr...
# 22                 documents/equipment/transshelf.pdf
# 23                   documents/equipment/waterway.pdf
# 24          documents/equipment/willem-van-oranje.pdf
#
#                            name year_of_construction  \
# 0                       ALEX II                 2006
# 1            Asian Hercules III                 2015
# 2                          BEAR                 1999
# 3                 BOKA VANGUARD                 2012
# 4                         BOXER                 2010
# 5   BSSIII Burial Sledge System                 None
# 6     Cornelius Backhoe Dredger                 1999
# 7                      Crestway                 2008
# 8                          EDAX                 1985
# 9                       GIANT 7                 2015
# 10                        FORTE                 2012
# 11                       Kamara                 2005
# 12                   MANU-PEKKA                 1983
# 13                      NDEAVOR                 2013
# 14                     NDURANCE                 2013
# 15                    Rockpiper                 2011
# 16                     Shoalway                 2010
# 17                     Shoreway                 2008
# 18                    Strandway                 2014
# 19                  Terra Plana                 2016
# 20                 Barent Zanen                 1984
# 21                     BEACHWAY                 2010
# 22                   TRANSSHELF                 1987
# 23                     Waterway                 2001
# 24            Willem van Oranje                 2010
#
#                                              capacity  \
# 0   Gross tonnage 548 GT, Net tonnage 164 NT, Leng...
# 1                        5,000 tons floating sheerleg
# 2   Bunker capacity fuel 1545 m3, fresh water 522 ...
# 3                    Deadweight 116,175 t / 130,000 t
# 4   Bunker capacity 378 cbm, Fuel: 378 m³, Fresh w...
# 5              Total installed jetting power 1,800 kW
# 6                                                None
# 7   Carrying capacity (D.W.) 8,350 t, Hopper capac...
# 8                                                None
# 9                                                None
# 10                                Deadweight 50,000 t
# 11  Bollard pull ahead 83 t, Deck area 450 m2, Dec...
# 12  Bucket capacity mud bucket 14 m3, Bucket capac...
# 13                                               None
# 14                         Turntable capacity 4,300 t
# 15  Rock installation capacity abt. 2,000 t/h. Ins...
# 16                           Hopper capacity 4,500 m3
# 17  Carrying capacity (D.W.) 8,350 t, Hopper capac...
# 18                           Hopper capacity 4,500 m3
# 19  Max. dredging depth 30 m (can be extended to 4...
# 20  Hopper capacity 8,116 m3, Carrying capacity 14...
# 21                           Hopper capacity 8,086 m3
# 22                                Deadweight 34,030 t
# 23  Carrying capacity (D.W.) 7,192 t, Hopper capac...
# 24  Hopper capacity 12,000 m3, Carrying capacity a...
#
#                                              built_by imo_number  \
# 0                           Yizheng Changrun Shipyard       None
# 1                                                None       None
# 2                                                None    9185932
# 3                            Hyundai Heavy Industries    9618783
# 4                                                None    9537537
# 5                                                None       None
# 6                               De Donge / Terramarre       None
# 7                                   IHC Dredgers B.V.       None
# 8                               Merwede Shipyard B.V.       None
# 9                   Keppel Nantong Shipyard Co., Ltd.       None
# 10                    Guangzhou Shipyard Int. Co. Ltd    9592848
# 11                                               None    9322607
# 12                                    OMP Oy, Finland       None
# 13                                               None    9650212
# 14  Samsung C&T corporation, ZPMC - Shanghai Zhenh...       None
# 15                          Keppel Singmarine Pte Ltd       None
# 16            Intervak scheepswerf & constructie b.v.       None
# 17                                  IHC Dredgers B.V.       None
# 18                                      Shipkits B.V.       None
# 19                                               None       None
# 20                                      IHC Smit B.V.       None
# 21              J.J.Sietas KG Schiffwerft GmbH u. Co.       None
# 22                             Turku Shipyard Finland    8512279
# 23                                   Merwede Shipyard       None
# 24                                  IHC Dredgers B.V.       None
#
#                                     port_of_registery  \
# 0                                                  []
# 1   [{'location': 'Singapore', 'country': 'Singapo...
# 2   [{'location': 'Antwerp', 'country': 'Belgium',...
# 3   [{'location': 'Willemstad', 'country': 'Curaça...
# 4   [{'location': 'Valletta', 'country': 'Malta', ...
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9   [{'location': 'Belgium', 'country': 'Belgium',...
# 10  [{'location': 'Valletta', 'country': 'Malta', ...
# 11  [{'location': 'Valletta', 'country': 'Malta', ...
# 12                                                 []
# 13  [{'location': 'Limassol', 'country': 'Cyprus',...
# 14                                                 []
# 15  [{'location': 'Limassol', 'country': 'Cyprus',...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19  [{'location': 'Papendrecht', 'country': 'The N...
# 20                                                 []
# 21                                                 []
# 22  [{'location': 'Willemstad', 'country': 'Curaça...
# 23                                                 []
# 24                                                 []
#
#                                           description
# 0   Floating grab dredger with no propulsion, unre...
# 1   A heavy lift vessel with a floating sheerleg c...
# 2   Offshore vessel used for anchor handling tug s...
# 3             Semi-submersible heavy transport vessel
# 4   Offshore vessel / Anchor handling tug (AHT) wi...
# 5   Boskalis has developed the burial tool BSSIII,...
# 6   Special service / Backhoe dredger - no propuls...
# 7   Trailing suction hopper dredger with mechanica...
# 8                              Cutter Suction Dredger
# 9   GIANT 7 is a cable lay barge with a classifica...
# 10  Semi-submersible DP-2 heavy transport vessel, ...
# 11  DP II Offshore Vessel / Anchor Handling Tug Su...
# 12  Backhoe dredger with a gross tonnage of 680 GT...
# 13  Multipurpose vessel with diesel electric propu...
# 14  Cable laying vessel with dynamic positioning s...
# 15  Subsea rock installation vessel with diesel el...
# 16  Trailing suction hopper dredger with shallow d...
# 17  Trailing suction hopper dredger with mechanica...
# 18  Trailing suction hopper dredger with features ...
# 19     Water Injection Dredger / Multi Purpose Vessel
# 20  Trailing suction hopper dredger with a gross t...
# 21                    TRAILING SUCTION HOPPER DREDGER
# 22            Semi-submersible heavy transport vessel
# 23  Trailing suction hopper dredger with shallow d...
# 24  Trailing suction hopper dredger with 2 separat...

# %% [markdown]
# ### Load Equipment to Neo4j

# %%
CREATE_EQUIPMENT_QUERY = """
    MERGE (e:Equipment {name: $name})
    SET  e.doc_path = $doc_path,
         e.year_of_construction = $year_of_construction,
         e.capacity = $capacity,
         e.imo_number = $imo_number,
         e.description = $description
    
    WITH e
    CALL (e) {
        MATCH (d:Document{doc_path: $doc_path})
        MERGE (e)-[:HAS_DOCUMENT]->(d)
    }
    
    WITH e
    CALL (e) {
        UNWIND $port_of_registery AS l
        MERGE (loc:Location {name: l.location})
        MERGE (country:Country {code: l.country_code})
        SET country.name = l.country
        MERGE (loc)-[:IN_COUNTRY]->(country)
        MERGE (e)-[:REGISTERED_AT]->(loc)
    }
    ;
"""

# %%
def insert_equipment_row(row):
    driver.execute_query(
        CREATE_EQUIPMENT_QUERY,
        name=row["name"],
        doc_path=row["doc_path"],
        year_of_construction=row["year_of_construction"],
        capacity=row["capacity"],
        built_by=row["built_by"],
        imo_number=row["imo_number"],
        description=row["description"],
        port_of_registery=row["port_of_registery"],
        database_=DATABASE,
        routing_=RoutingControl.WRITE,
    )

# %%
for idx, row in equipment_df.iterrows():
    insert_equipment_row(row)

# %% [markdown]
# ## Resolve duplicate Entities

# %% [markdown]
# Refactor locations in countries

# %%
df = driver.execute_query(
    """
        MATCH ()-[r1]-(l:Location)-[r2:IN_COUNTRY]-(c:Country)
        WHERE l.name = c.name
        DELETE r2
        WITH r1, c
        CALL apoc.refactor.to(r1, c) YIELD input, output
        RETURN input, output
    """,
    database_=DATABASE,
    routing_=RoutingControl.WRITE,
    result_transformer_=lambda r: r.to_df()
)

# %% [markdown]
# Refactor equipment names

# %%
merged_df = driver.execute_query(
    """
        MATCH (e1:Equipment)
        WHERE e1.doc_path IS NOT NULL
        CALL (e1) {
         MATCH (e2:Equipment)
         WITH e1, e2, 
         apoc.text.join(apoc.coll.sort(split(trim( apoc.text.replace(apoc.text.replace(lower(e1.name), "[^a-z0-9 ]", " "), "\\s+", " ")), " ")), " ") as normalized_1,
         apoc.text.join(apoc.coll.sort(split(trim( apoc.text.replace(apoc.text.replace(lower(e2.name), "[^a-z0-9 ]", " "), "\\s+", " ")), " ")), " ") as normalized_2
         WHERE e1 <> e2 AND (LOWER(replace(normalized_2, " ", "")) CONTAINS LOWER(replace(normalized_1, " ", "")) OR (apoc.text.replace(lower(e2.name), "[^a-z0-9 ]", " ") CONTAINS apoc.text.replace(lower(e1.name), "[^a-z0-9 ]", " ")))
         WITH e1, e2 
         OPTIONAL MATCH (:Project)-[r]->(e2)
         CALL apoc.refactor.to(r, e1) YIELD input, output
         WITH COLLECT(e2.name) as similar_names
         RETURN similar_names
        }
        WITH e1, similar_names
        CALL (similar_names) {
          UNWIND similar_names as name
          MATCH (e:Equipment{name: name})
          DELETE e
        }
        WITH e1, similar_names
        RETURN e1.name, similar_names
    """,
    database_=DATABASE,
    routing_=RoutingControl.WRITE,
    result_transformer_=lambda r: r.to_df()
)
merged_df
# Out:
#                         e1.name  \
# 0            Asian Hercules III
# 1             Willem van Oranje
# 2                      Waterway
# 3                       ALEX II
# 4                          BEAR
# 5                 BOKA VANGUARD
# 6                         BOXER
# 7   BSSIII Burial Sledge System
# 8     Cornelius Backhoe Dredger
# 9                      Crestway
# 10                         EDAX
# 11                      GIANT 7
# 12                        FORTE
# 13                       Kamara
# 14                   MANU-PEKKA
# 15                      NDEAVOR
# 16                     NDURANCE
# 17                     Shoalway
# 18                    Strandway
# 19                  Terra Plana
# 20                    Rockpiper
# 21                     Shoreway
# 22                 Barent Zanen
# 23                     BEACHWAY
# 24                   TRANSSHELF
#
#                                        similar_names
# 0                                                 []
# 1   [TSHD Willem van Oranje, TSHD Willem van Oranje]
# 2                                    [TSHD Waterway]
# 3                                          [Alex II]
# 4                                       [Union Bear]
# 5                                 [MV Boka Vanguard]
# 6                                      [Union Boxer]
# 7                                                 []
# 8                                                 []
# 9                                    [TSHD Crestway]
# 10               [Edax, Cutter suction dredger Edax]
# 11                         [Cable Lay Barge Giant 7]
# 12                                           [Forte]
# 13                                     [Smit Kamara]
# 14                      [BHD Manu Pekka, Manu Pekka]
# 15               [Cable Lay Vessel Ndeavor, NDeavor]
# 16             [NDurance, Cable Lay Vessel Ndurance]
# 17                    [TSHD Shoalway, TSHD Shoalway]
# 18                                  [TSHD Strandway]
# 19                                 [WID Terra Plana]
# 20                                                []
# 21                                                []
# 22                             [TSHd 'Barent Zanen']
# 23                                        [Beachway]
# 24                                      [Transshelf]

# %%
equipment_names_df = driver.execute_query(
    """
        MATCH (e1:Equipment)
        WHERE e1.doc_path IS NOT NULL
        RETURN e1.name as equipment_name
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_=lambda r: r.to_df()
)
equipment_names = list(equipment_names_df['equipment_name'])

# %%
equipment_names_df = driver.execute_query(
    """
        MATCH (e1:Equipment)
        WHERE e1.doc_path IS NULL
        RETURN e1.name as equipment_name
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_=lambda r: r.to_df()
)
parsed_names = list(equipment_names_df['equipment_name'])

# %%
def detect_duplicates(equipment_names, parsed_names):
    prompt = f"""
        You are an entity resolution assistant.
        Given the following list of equipment names:
        equipment_names:
        {equipment_names}

        can you find any equipment names in the following list that describe the same equipment?
        potential_duplicates:
        {parsed_names}
        
        Return ONLY a JSON object with the following structure:
        {{
            "groups": [
                {{
                    "canonical": "<name>",
                    "duplicates": ["duplicate1", "duplicate2", ...]
                }},
                ...
            ]
        }}
        
        Rules:
        - Only include TRUE duplicates (different spellings or formatting of the same equipment).
        - Do NOT include generic categories (e.g., "TSHDs"). 
        - Please focus on equipment names instead of generic descriptions (Grab dredger can be ignored). 
        - If the duplicates list is empty, don't return the group. Only return groups with duplicates.
        - Only return the JSON object no prefix or whatsoever. 
        - The canonical should always come from the equipment name. The duplicates can only be coming from the potential_duplicates.
    """

    response = client.chat.completions.create(
        model=LLM,
        messages=[{"role": "user", "content": prompt}]
    )
    content = response.choices[0].message.content.strip()[8:-4]
    try:
        data = json.loads(content)
    except json.JSONDecodeError:
        raise ValueError("LLM returned invalid JSON:\n" + content)
    return data

# %%
data = detect_duplicates(equipment_names, parsed_names)

# %%
data
# Out:
# {'groups': [{'canonical': 'BSSIII Burial Sledge System',
#    'duplicates': ['Burial Sledge BSS-III']},
#   {'canonical': 'Cornelius Backhoe Dredger', 'duplicates': ['Cornelius']},
#   {'canonical': 'Willem van Oranje',
#    'duplicates': ['Oranje', 'TSHD ‘Oranje’']}]}

# %%
def merge_duplicate_group(canonical, duplicates):
    print(f"Merging duplicates into: {canonical}")

    driver.execute_query(
        """
            MATCH (c:Equipment {name: $canonical})
            WHERE c.doc_path IS NOT NULL
            WITH c
            UNWIND $dups AS dupName
                MATCH (d:Equipment {name: dupName})
                OPTIONAL MATCH (p)-[r]->(d)
                CALL apoc.refactor.to(r, c) YIELD input, output
                DETACH DELETE d
            RETURN c.name AS kept
        """,
        database_=DATABASE,
        canonical=canonical,
        dups=duplicates,
        routing_=RoutingControl.WRITE,
        result_transformer_=lambda r: r.to_df()
    )

# %%
data['groups']
# Out:
# [{'canonical': 'BSSIII Burial Sledge System',
#   'duplicates': ['Burial Sledge BSS-III']},
#  {'canonical': 'Cornelius Backhoe Dredger', 'duplicates': ['Cornelius']},
#  {'canonical': 'Willem van Oranje', 'duplicates': ['Oranje', 'TSHD ‘Oranje’']}]

# %%
for group in data['groups']:
    canonical = group["canonical"]
    duplicates = group["duplicates"]
    merge_duplicate_group(canonical, duplicates)
# Out:
# Merging duplicates into: BSSIII Burial Sledge System
# Merging duplicates into: Cornelius Backhoe Dredger
# Merging duplicates into: Willem van Oranje

# %%
driver.execute_query(
    """
    MATCH (a)-[r:USED_EQUIPMENT]->(b)
    WITH a, b, collect(r) AS rels
    WHERE size(rels) > 1
    FOREACH (r IN rels[1..] | DELETE r)
    """,
    database_=DATABASE,
    routing_=RoutingControl.WRITE,
    result_transformer_=lambda r: r.to_df()
)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Delete doc_path from Project/Equipment

# %% [markdown]
# Now that we have relations to documents we can delete the doc_path from Project and Equipment and give the URL instead.

# %%
driver.execute_query(
    """
    MATCH (p:Project|Equipment)
    SET p.doc_path = NULL
    """,
    database_=DATABASE,
    routing_=RoutingControl.WRITE,
    result_transformer_=lambda r: r.to_df()
)

# %%
driver.execute_query(
    """
    MATCH (p:Project|Equipment)-[]-(d:Document)
    SET p.url = d.url
    """,
    database_=DATABASE,
    routing_=RoutingControl.WRITE,
    result_transformer_=lambda r: r.to_df()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 driver.execute_query(
#       2     """
#       3     MATCH (p:Project|Equipment)-[]-(d:Document)
#       4     SET p.url = d.url
#       5     """,
#       6     database_=DATABASE,
#       7     routing_=RoutingControl.WRITE,
#       8     result_transformer_=lambda r: r.to_df()
#       9 )
#
# NameError: name 'driver' is not defined
