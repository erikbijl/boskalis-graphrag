# %% [markdown]
# # Module 2 - Create Indexes

# %% [markdown]
# This notebook creates a Vector Index on top of the embeddings in Neo4j. This can be used later on for a vector search in the database. Documentation of the vector index in Neo4j can be found here: [Neo4j Vector Index and Search](https://neo4j.com/labs/genai-ecosystem/vector-search/?msclkid=c56d8efbd9a0151f76ebea164f5643cb&utm_source=Google&utm_medium=PaidSearch&utm_campaign=Evergreen&utm_content=EMEA-Search-SEMCE-DSA-None-SEM-SEM-NonABM&utm_term=&utm_adgroup=DSA&gad_source=1&gclid=Cj0KCQjw9vqyBhCKARIsAIIcLMEVATnevK1iXdTlPzxCK8eytADNy4tWZXXRF_NAthTi4x_sO19uUP4aAubSEALw_wcB).
#
# Again, for executing the queries we make use of [Python Driver](https://neo4j.com/docs/api/python-driver/current/) that enables querying Neo4j from a Python script

# %%
import pandas as pd
from neo4j import Query, GraphDatabase, RoutingControl, Result
import os
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings
from json import loads, dumps
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# ## Get Credentials

# %%
env_file = 'credentials.env'

# %%
if os.path.exists(env_file):
    load_dotenv(env_file, override=True)

    # Neo4j
    HOST = os.getenv('NEO4J_URI')
    USERNAME = os.getenv('NEO4J_USERNAME')
    PASSWORD = os.getenv('NEO4J_PASSWORD')
    DATABASE = os.getenv('NEO4J_DATABASE')

    # AI
    OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
    os.environ['OPENAI_API_KEY']=OPENAI_API_KEY
    LLM = os.getenv('LLM')
    EMBEDDINGS_MODEL = os.getenv('EMBEDDINGS_MODEL')
else:
    print(f"File {env_file} not found.")

# %% [markdown]
# ## Setup Connection to Database

# %% [markdown]
# Setup connection to the database with the [Python Driver](https://neo4j.com/docs/python-manual/5/).

# %%
driver = GraphDatabase.driver(
    HOST,
    auth=(USERNAME, PASSWORD)
)

# %% [markdown]
# Test the connection

# %%
driver.execute_query(
    """
    MATCH (n) RETURN COUNT(n) as Count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    Count
# 0   1132

# %% [markdown]
# ## Create Vector Index

# %% [markdown]
# Convert the embeddings to a vector property with the [setNodeVectorProperty](https://neo4j.com/docs/operations-manual/5/reference/procedures/#procedure_db_create_setNodeVectorProperty) procedure.

# %%
no_chunks = driver.execute_query(
    """
    MATCH (n:Chunk) RETURN COUNT(n) as Count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
no_chunks
# Out:
#    Count
# 0    862

# %%
batch_size = 100
nr_batches = int(no_chunks.iloc[0].Count / batch_size) + 1
print(f'Running {nr_batches} batches with size {batch_size}')
# Out:
# Running 9 batches with size 100

# %%
for batch in range(nr_batches):
    query = f"""
        MATCH(c:Chunk)
        WHERE c.id >= {(batch*batch_size)+1} AND c.id <= {(batch+1)*batch_size}
        CALL db.create.setNodeVectorProperty(c, "embedding", c.embedding)
        RETURN count(c) AS propertySetCount
    """

    driver.execute_query(
        query,
        database_=DATABASE,
        routing_=RoutingControl.WRITE,
    )
    
    if ((batch % 10 == 0) & (batch != 0)):
        print(f"Finished: {batch}/{nr_batches} batches ({round(batch/nr_batches*100,2)}%)")

# %% [markdown]
# Create the [vector index](https://neo4j.com/docs/cypher-manual/current/indexes/semantic-indexes/vector-indexes/#create-vector-index) on Embeddings in Neo4j

# %%
query = """
    CREATE VECTOR INDEX `chunk-embeddings` IF NOT EXISTS
    FOR (c:Chunk) ON (c.embedding)
    OPTIONS {
        indexConfig: {
            `vector.dimensions`: 1536,
            `vector.similarity_function`: 'cosine'
        } 
    }
"""

# %%
driver.execute_query(
    query,
    database_=DATABASE,
    routing_=RoutingControl.WRITE
)
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x31142a6d0>, keys=[])

# %% [markdown]
# Show the result

# %%
schema_result_df  = driver.execute_query(
    'SHOW INDEXES',
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
schema_result_df.head()
# Out:
#    id              name       state  populationPercent    type    entityType  \
# 0   2  chunk-embeddings  POPULATING                0.0  VECTOR          NODE
# 1   0    index_343aff4e      ONLINE              100.0  LOOKUP          NODE
# 2   1    index_f7700477      ONLINE              100.0  LOOKUP  RELATIONSHIP
#
#   labelsOrTypes   properties     indexProvider owningConstraint  \
# 0       [Chunk]  [embedding]        vector-2.0             None
# 1          None         None  token-lookup-1.0             None
# 2          None         None  token-lookup-1.0             None
#
#                               lastRead  readCount
# 0                                 None        NaN
# 1  2025-12-19T15:13:41.330000000+00:00    37584.0
# 2  2025-12-10T16:34:56.212000000+00:00       10.0

# %% [markdown]
# ## Experiment with the Vector Search

# %% [markdown]
# Define the Embeddings Model

# %%
embedding_model = OpenAIEmbeddings(
    model=EMBEDDINGS_MODEL,
    openai_api_key=OPENAI_API_KEY
)

# %%
embedding_model.model
# Out:
# 'text-embedding-ada-002'

# %% [markdown]
# Define the function to perform a Vector Search

# %%
def vector_search_chunks(message, nn=5, embedding_model=embedding_model):
    message_vector = embedding_model.embed_query(message)
    similarity_query = """ 
        CALL db.index.vector.queryNodes("chunk-embeddings", $nn, $message_vector) YIELD node, score
        WITH node as chunk, score ORDER BY score DESC
        MATCH (d:Document)<-[:PART_OF]-(chunk)
        RETURN score, d.name as doc_name, d.url as doc_url, chunk.id as chunk_id, chunk.page as page, chunk.text as text
    """
    results_df = driver.execute_query(
        similarity_query,
        database_=DATABASE,
        routing_=RoutingControl.READ,
        message_vector=message_vector,
        nn = nn, 
        result_transformer_= lambda r: r.to_df()
    )
    return results_df

# %% [markdown]
# #### Example

# %% [markdown]
# Let's run an example with the vector search on the chunks. Examples:
#
# - "Did we do any project on Offshore Windfarms?"
# - "In which project was ALEX II used?"
# - "What project did we do in the Netherlands?"
# - "In which projects did we build a deepwall?"
# - "In which year was the ship STRANDWAY?"
# - "What are some features of the ship STRANDWAY?" (struggling).

# %%
message = "What are some features of the ship STRANDWAY?"

# %%
results_df = vector_search_chunks(message, 10, embedding_model)

# %%
results_df
# Out:
#       score                doc_name  \
# 0  0.909225            ndurance.pdf
# 1  0.909119  le-havre-port-2000.pdf
# 2  0.907196          bear-27-03.pdf
# 3  0.906357            ndurance.pdf
# 4  0.904755            waterway.pdf
# 5  0.901627           rockpiper.pdf
# 6  0.900330         ndeavor_mpv.pdf
# 7  0.900131            ndurance.pdf
# 8  0.899887         ndeavor_mpv.pdf
# 9  0.899826             giant-7.pdf
#
#                                              doc_url  chunk_id  page  \
# 0   https://boskalis.com/media/wbanffyp/ndurance.pdf       803     0
# 1  https://boskalis.com/media/wivdqakk/le-havre-p...       557     1
# 2  https://boskalis.com/media/rathdvla/bear-27-03...       758     1
# 3   https://boskalis.com/media/wbanffyp/ndurance.pdf       804     0
# 4   https://boskalis.com/media/gwfevulh/waterway.pdf       838     0
# 5  https://boskalis.com/media/qlmpx404/rockpiper.pdf       722     0
# 6  https://boskalis.com/media/jpwb2uu5/ndeavor_mp...       667     0
# 7   https://boskalis.com/media/wbanffyp/ndurance.pdf       800     0
# 8  https://boskalis.com/media/jpwb2uu5/ndeavor_mp...       669     0
# 9    https://boskalis.com/media/okxnnsxz/giant-7.pdf       827     0
#
#                                                 text
# 0  accommodation barge, bottom \nstrengthened for...
# 1  managed to achieve this goaol.\n \nEQUIPMENT D...
# 2  Capstan winches Brattvaag 5 t\nTugger winches ...
# 3  Two engine rooms.\nBeaching capability.\nCorri...
# 4  H.S. <= 2.5 m. Unrestricted navigation. \nFEAT...
# 5  Length overall  158.60 m\nBreadth  36.00 m\nMo...
# 6  2 x Boatlandings\nA - Frame 100 t SWL\nMAIN DA...
# 7  EQUIPMENT\nSHEET\nNDURANCE \nCABLE LAYING VESS...
# 8  Main engines  7,280 kW\nStern thrusters  2 x 1...
# 9  CONSTRUCTION / CLASSIFICATION\nYear of constru...

# %%
results = dumps(loads(results_df.to_json(orient="records")), indent=2)
print(results)
# Out:
# [
#   {
#     "score": 0.9092254639,
#     "doc_name": "ndurance.pdf",
#     "doc_url": "https://boskalis.com/media/wbanffyp/ndurance.pdf",
#     "chunk_id": 803,
#     "page": 0,
#     "text": "accommodation barge, bottom \nstrengthened for loading and unloading \naground\nFEATURES\nCompletely new ship and turntable design.\nDiesel electric propulsion system.\nAccommodation on fore ship, total for 98 persons\nTwo engine rooms.\nBeaching capability."
#   },
#   {
#     "score": 0.9091186523,
#     "doc_name": "le-havre-port-2000.pdf",
#     "doc_url": "https://boskalis.com/media/wivdqakk/le-havre-port-2000.pdf",
#     "chunk_id": 557,
#     "page": 1,
#     "text": "managed to achieve this goaol.\n \nEQUIPMENT DEPLOYED\n \u0082 TSHD Shoalway\n \u0082 TSHD Strandway\n \u0082 TSHD Willem van Oranje\n \u0082 GD Medusa\n \u0082 WID Terra Plana\n \u0082 Additional equipment such as multicat, survey \nlaunch, hopper barges\nSPECIAL CIRCUMSTANCES"
#   },
#   {
#     "score": 0.9071960449,
#     "doc_name": "bear-27-03.pdf",
#     "doc_url": "https://boskalis.com/media/rathdvla/bear-27-03.pdf",
#     "chunk_id": 758,
#     "page": 1,
#     "text": "Capstan winches Brattvaag 5 t\nTugger winches Brattvaag 2 x 10 t\nDECK EQUIPMENT \nStern roller L: 6.0 m x 3.0 m diam. SWL 500 t\nCrane 5 t @  14 m\nTowing pins Karmoy KWT 350-800 / SWL 240 t\nKarmoy pins 2 x 500 t SWL\nGypsy wheels 2 x 76 mm / 2 x 84 mm\nChain lockers capacity 2 x 130 m 3\nSIDE VIEW"
#   },
#   {
#     "score": 0.9063568115,
#     "doc_name": "ndurance.pdf",
#     "doc_url": "https://boskalis.com/media/wbanffyp/ndurance.pdf",
#     "chunk_id": 804,
#     "page": 0,
#     "text": "Two engine rooms.\nBeaching capability.\nCorridor under accommodation to handle projects at the bow.\n7 point mooring system due to Ploughing modus  \n(bow 7th anchor wire).\nLaunch & recovery trencher with A-frame is used for: \nTrenchformer, SMD HD3 Plough, joint repair, Quadrant MBR 5 m"
#   },
#   {
#     "score": 0.9047546387,
#     "doc_name": "waterway.pdf",
#     "doc_url": "https://boskalis.com/media/gwfevulh/waterway.pdf",
#     "chunk_id": 838,
#     "page": 0,
#     "text": "H.S. <= 2.5 m. Unrestricted navigation. \nFEATURES\nShallow draught and large loading capacity.\nAwarded \"Ship of the year 2002\": the most technically-\ninnovative vessel built. \nMAIN DATA\nGross tonnage   5,393 GT\nLength overall   97.70 m\nBreadth   23.00 m\nMoulded depth   7.00 m"
#   },
#   {
#     "score": 0.9016265869,
#     "doc_name": "rockpiper.pdf",
#     "doc_url": "https://boskalis.com/media/qlmpx404/rockpiper.pdf",
#     "chunk_id": 722,
#     "page": 0,
#     "text": "Length overall  158.60 m\nBreadth  36.00 m\nMoulded depth  13.50 m\nDesign draught  9.40 m\nCargo carrying capacity  24,000 t\nCargo hold capacity 15,500 m\u00b3\nSailing speed loaded 12.0 kn\nTotal installed power  15,192 kW (3 x 4,500 kW +  \n  1 x 1,200 kW + 1 x 492 kW)\nMain engines  3 x 4,500 kW"
#   },
#   {
#     "score": 0.9003295898,
#     "doc_name": "ndeavor_mpv.pdf",
#     "doc_url": "https://boskalis.com/media/jpwb2uu5/ndeavor_mpv.pdf",
#     "chunk_id": 667,
#     "page": 0,
#     "text": "2 x Boatlandings\nA - Frame 100 t SWL\nMAIN DATA \nDynamic positioning system DP-2 (Kongsberg)  \nPositioning sensors  1 x HiPAP, 3 x DGPS, 1 x alarm \n    printer, 2 x UPS 1 x Cyscan\nLength overall  99.00 m (excl. helideck)\nBreadth   30.00 m\nMoulded depth   7.00 m"
#   },
#   {
#     "score": 0.9001312256,
#     "doc_name": "ndurance.pdf",
#     "doc_url": "https://boskalis.com/media/wbanffyp/ndurance.pdf",
#     "chunk_id": 800,
#     "page": 0,
#     "text": "EQUIPMENT\nSHEET\nNDURANCE \nCABLE LAYING VESSEL\nMAIN DATA\nDynamic positioning system DP-2\nLength overall 99.00 m\nBreadth 30.00 m\nMoulded depth 7.00 m\nDesign draught 4.8 m\nDisplacement 12,285 t\nTurntable capacity 4,300 t\nOuter diameter 26 m\nInner diameter 3-6 m (adjustable)"
#   },
#   {
#     "score": 0.899887085,
#     "doc_name": "ndeavor_mpv.pdf",
#     "doc_url": "https://boskalis.com/media/jpwb2uu5/ndeavor_mpv.pdf",
#     "chunk_id": 669,
#     "page": 0,
#     "text": "Main engines  7,280 kW\nStern thrusters  2 x 1,250 kW azimuth thrusters\nBow thrusters  2 x 1,000 kW retractable  \n   azimuth thrusters, 1 x 550 kW \n   tunnel thrusters \nCARGO CAPACITY\nDeck area  1,860 m2\nFree deck length / width  70 m x 29 m\nDeck load  15 t/m2\nBunker capacity  2,193 m3"
#   },
#   {
#     "score": 0.8998260498,
#     "doc_name": "giant-7.pdf",
#     "doc_url": "https://boskalis.com/media/okxnnsxz/giant-7.pdf",
#     "chunk_id": 827,
#     "page": 0,
#     "text": "CONSTRUCTION / CLASSIFICATION\nYear of construction 2015\nClassification Lloyd\u2019s Register\nClass notation Crane Barge\nFlag State Belgium\nOwner Boskalis\nYard Keppel Nantong Shipyard Co., Ltd. \nACCOMMODATION\nCabins:  \n73 berths. Messroom and galley, hospital, recreation room,"
#   }
# ]

# %% [markdown]
# #### View results in the Neo4j Browser

# %% [markdown]
# Create a vector from a searchprompt

# %%
search_prompt = "Boskalis Ship the BEAR"

query_vector = embedding_model.embed_query(search_prompt)
print(query_vector)
# Out:
# [-0.012081247754395008, -0.02560073882341385, -0.0031538631301373243, -0.0037462827749550343, -0.01857389137148857, 0.014272857457399368, -0.037723079323768616, 0.009903335943818092, 0.01931355893611908, -0.018916331231594086, 0.008307570591568947, 0.0023645414039492607, -0.007321345619857311, -0.024285774677991867, 0.008841775357723236, 0.009006145410239697, 0.007629540748894215, 0.004273638594895601, 0.024299470707774162, 0.00753365783020854, -0.018971120938658714, 0.024422749876976013, 0.024600816890597343, 0.006383062805980444, 0.00819798931479454, -0.0115949846804142, 0.03980511054396629, -0.014204369857907295, -0.010019765235483646, 0.003075102111324668, -0.0017806828254833817, -0.0044037653133273125, -0.023915939033031464, -0.007074789609760046, -0.02131340280175209, -0.022847529500722885, 0.017724642530083656, -0.003708614269271493, 0.003989414311945438, -0.0014784804079681635, 0.009225307032465935, 0.0011523072607815266, 0.0007139852968975902, -0.0101361945271492, -0.007355589885264635, -0.0014117048121988773, -0.01713564805686474, -0.013389364816248417, -0.0027703314553946257, -0.004708536434918642, 0.03081950917840004, 0.016642535105347633, -0.022724252194166183, 0.003258306998759508, 0.027162261307239532, 0.019039608538150787, 0.004961940925568342, -0.025477461516857147, 0.00637963879853487, -0.006393336225301027, 0.011615530587732792, -0.0013158218935132027, -0.011019687168300152, 0.005294106900691986, -0.005335199646651745, -0.021080544218420982, -0.010608760640025139, -0.004708536434918642, -0.0045784092508256435, -0.01895742304623127, 0.024792583659291267, -0.0001532414462417364, -0.006348819006234407, 0.01761506125330925, 0.02009432017803192, -0.0029501121025532484, 0.0077322726137936115, 0.008369209244847298, -0.009191063232719898, 0.0006960072787478566, 0.022779041901230812, -0.042106300592422485, -0.010184136219322681, 0.016012446954846382, 0.024217285215854645, 0.007581599522382021, -0.010204682126641273, 0.011992214247584343, -0.0258472952991724, 0.0041640582494437695, 0.03139480575919151, -0.000601408479269594, -0.014327648095786572, 0.01710825227200985, 0.010958047583699226, 0.011601833626627922, -0.005691336002200842, 0.02136819437146187, -0.006215267814695835, -0.038407959043979645, 0.017957501113414764, -0.016026144847273827, -0.022066768258810043, -0.006831658072769642, -0.03388776257634163, 0.009410223923623562, -0.017628759145736694, 0.004081872757524252, 0.02384745143353939, -0.002251536352559924, -0.0034055558498948812, 0.0463799387216568, 0.009718419052660465, -0.031641364097595215, 0.01731371507048607, -0.006746048107743263, -0.013019531033933163, -0.020738106220960617, 0.005465326365083456, -0.01672472059726715, 0.014683783985674381, 0.017163041979074478, -0.0010684096487239003, -0.012916798703372478, -0.0013962950324639678, 0.02983328513801098, -0.0235735010355711, -0.02486107125878334, -0.015615218318998814, 1.1764652299461886e-05, 0.007656936068087816, -0.005492721684277058, 0.0007936023757793009, 2.875952486647293e-05, -0.014067393727600574, 0.007581599522382021, -0.03621634840965271, 0.012937345542013645, 0.00728025333955884, -0.01056766789406538, 0.0037325851153582335, 0.026902006939053535, -0.02131340280175209, 0.005396838765591383, -0.028682690113782883, 0.019957344979047775, 0.008382907137274742, 0.022395510226488113, -0.008013072423636913, -0.014313950203359127, 0.034052133560180664, -0.014355042949318886, -0.003712038742378354, -0.009054087102413177, 0.0010016340529546142, 0.012136038392782211, -0.01949162781238556, 0.02871008589863777, -0.020135413855314255, -0.02471039816737175, 0.004006536211818457, 0.016793208196759224, 0.004818116780370474, -0.017779432237148285, 0.01603984273970127, 0.03646290302276611, 0.013875627890229225, 0.007978828623890877, -0.009691023267805576, -0.010506028309464455, -0.005040701944380999, 0.007136428728699684, -0.023244759067893028, 0.02706637792289257, 0.010218380019068718, 0.019505325704813004, -0.007047394756227732, 0.009533502161502838, -0.009588 ...

# %% [markdown]
# Now take the embedding above and paste the following query in the browser:
#
# :params query_vector => [-0.005233455915004015, -0.01934160105884075, 0.008535362780094147, -0.0051453616470098495, -0.017919041216373444, 0.008372224867343903, -0.017671070992946625, 0.007941541261970997, 0.014212552458047867, -0.028790533542633057, 0.0048027727752923965, 0.01440831832587719, -0.016509531065821648, -0.018245315179228783, 0.01389932818710804, 0.003270910121500492, 0.026937291026115417, 0.00868544913828373, 0.033253978937864304, 0.009886141866445541, 0.003680385649204254, 0.015413246117532253, 0.0036281815264374018, -0.009377152658998966, -0.0021419974509626627, -0.010284198448061943, 0.02236943505704403, -0.01917193830013275, 0.012548549100756645, -0.01652258262038231, -0.0016069059493020177, -0.009807836264371872, -0.02051619254052639, -0.017005469650030136, -0.022408589720726013, -0.003332902444526553, -0.007458653766661882, -0.0034650438465178013, 0.01974618248641491, 0.00012276109191589057, 0.0134294917806983, 0.0003668558201752603, -0.008065525442361832, -0.00263956724666059, -0.008365699090063572, -0.008848587051033974, -0.023113343864679337, -0.017149031162261963, -0.023100292310118675, 0.00544553529471159, 0.024783873930573463, 0.003133874386548996, -0.005350915249437094, -0.014695440419018269, 0.02458810806274414, 0.021338405087590218, 0.0034030515234917402, 0.006071983836591244, -0.018075652420520782, -0.022904526442289352, 0.010440810583531857, 0.015321888960897923, -0.0012104813940823078, -0.0021795190405100584, 0.0023377626203000546, -0.007647893391549587, 0.017762428149580956, 0.016470378264784813, -0.009220540523529053, 0.018414979800581932, 0.025123199447989464, 0.019954998046159744, 0.031322430819272995, 0.012391936965286732, 0.008163408376276493, 0.01144573837518692, 0.007151954807341099, 0.004466709215193987, 0.013129319064319134, -0.010192841291427612, 0.005706555210053921, -0.01925024390220642, -0.012411513365805149, -0.01144573837518692, 0.01533493958413601, 0.0009771946351975203, -0.015543756075203419]

# %% [markdown]
# Now observe the result back in the browser for a search on chunks:
#
# ```
# CALL db.index.vector.queryNodes("chunk-embeddings", 3, $query_vector) YIELD node, score
# WITH node as chunk, score ORDER BY score DESC
# RETURN score, chunk
# ```

# %% [markdown]
# ### Create Full Text Index

# %%
schema_result_df  = driver.execute_query(
    'CREATE FULLTEXT INDEX full_text_name IF NOT EXISTS FOR (n:Equipment|Project|Client|Contractor) ON EACH [n.name]',
    database_=DATABASE,
    routing_=RoutingControl.WRITE,
    result_transformer_= lambda r: r.to_df()
)
schema_result_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
schema_result_df  = driver.execute_query(
    'SHOW INDEXES',
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
schema_result_df.head()
# Out:
#    id              name   state  populationPercent      type    entityType  \
# 0   2  chunk-embeddings  ONLINE              100.0    VECTOR          NODE
# 1   3    full_text_name  ONLINE              100.0  FULLTEXT          NODE
# 2   0    index_343aff4e  ONLINE              100.0    LOOKUP          NODE
# 3   1    index_f7700477  ONLINE              100.0    LOOKUP  RELATIONSHIP
#
#                               labelsOrTypes   properties     indexProvider  \
# 0                                   [Chunk]  [embedding]        vector-2.0
# 1  [Equipment, Project, Client, Contractor]       [name]      fulltext-1.0
# 2                                      None         None  token-lookup-1.0
# 3                                      None         None  token-lookup-1.0
#
#   owningConstraint                             lastRead  readCount
# 0             None  2025-12-19T15:15:22.693000000+00:00        1.0
# 1             None                                 None        NaN
# 2             None  2025-12-19T15:15:21.625000000+00:00    37593.0
# 3             None  2025-12-10T16:34:56.212000000+00:00       10.0

# %%
results_df  = driver.execute_query(
    """
    CALL db.index.fulltext.queryNodes("full_text_name", "s STRANdway") YIELD node, score
    RETURN node.name, score
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
results = dumps(loads(results_df.to_json(orient="records")), indent=2)

print(results)
# Out:
# [
#   {
#     "node.name": "Strandway",
#     "score": 3.0028965473
#   }
# ]
